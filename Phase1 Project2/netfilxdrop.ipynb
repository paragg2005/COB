# %% [markdown]
# # Dropping Values to obtain clean Dataset -> 2nd Method

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("C:/Users/gunda/Desktop/ML_projects/data/dataset - netflix1.csv")
dataset
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset.replace("Not Given",np.nan,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2588
# country          287
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#      show_id     type                              title  \
# 0         s1    Movie               Dick Johnson Is Dead
# 1         s3  TV Show                          Ganglands
# 2         s6  TV Show                      Midnight Mass
# 3        s14    Movie   Confessions of an Invisible Girl
# 4         s8    Movie                            Sankofa
# ...      ...      ...                                ...
# 6565   s3351    Movie         True: Grabbleapple Harvest
# 6566   s3509    Movie             True: Tricky Treat Day
# 6567   s3554  TV Show       True and the Rainbow Kingdom
# 6568   s4241    Movie  Sam Kinison: The Scream Continues
# 6569   s1315  TV Show                   Chappelle's Show
#
#                           director        country  date_added  release_year  \
# 0                  Kirsten Johnson  United States   9/25/2021          2020
# 1                  Julien Leclercq         France   9/24/2021          2021
# ...

# %%
dataset.to_csv("CleanedDataSet_drop.csv")
